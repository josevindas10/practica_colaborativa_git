# %% [markdown]
# <a href="https://colab.research.google.com/github/josevindas10/practica_colaborativa_git/blob/main/Practica_Colaborativa_GitHub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Práctica colaborativa: NumPy + Pandas con Google Colab y GitHub
#
# ## Propósito
# Esta actividad tiene como objetivo practicar ejercicios básicos de **NumPy** y **Pandas**, al mismo tiempo que se utiliza la integración entre **Google Colab y GitHub** para trabajar de forma colaborativa y secuencial sobre un mismo notebook.
#
# ## Modalidad de trabajo
# - Trabajen en parejas.
# - Ambos integrantes deben estar conectados por **Zoom**.
# - Durante toda la actividad, la persona que esté programando debe **compartir pantalla**.
# - El trabajo se realizará sobre **un único archivo `.ipynb` almacenado en GitHub**.
# - **Estudiante A** resuelve primero los ejercicios 1 y 2.
# - Al finalizar el ejercicio 2, Estudiante A guarda el notebook actualizado en GitHub.
# - **Estudiante B** abre desde GitHub la versión actualizada y resuelve los ejercicios 3 y 4.
# - Al finalizar, Estudiante B guarda nuevamente el notebook en GitHub.
#
# > **Importante:** No trabajen simultáneamente sobre dos copias diferentes del notebook. El objetivo es practicar un flujo de trabajo secuencial utilizando GitHub como repositorio compartido.

# %% [markdown]
# ## Flujo de trabajo con Google Colab y GitHub
#
# 1. Una persona del grupo debe tener el notebook dentro de un repositorio de GitHub.
# 2. Abra el archivo desde Google Colab usando **Archivo > Abrir cuaderno > GitHub**.
# 3. Busque el repositorio y abra este notebook.
# 4. Estudiante A resuelve los ejercicios 1 y 2.
# 5. Guarde los cambios usando **Archivo > Guardar una copia en GitHub**.
# 6. Estudiante B debe volver a abrir desde GitHub la versión más reciente del notebook.
# 7. Estudiante B resuelve los ejercicios 3 y 4.
# 8. Guarde nuevamente la versión final en GitHub.
#
# ### Recomendación para los commits
# - Primer guardado: `Ejercicios 1 y 2 completados - Nombre Estudiante A`
# - Segundo guardado: `Ejercicios 3 y 4 completados - Nombre Estudiante B`

# %% [markdown]
# ## Preparación del entorno
#
# Ejecute la siguiente celda antes de comenzar.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Bloque 1 — Estudiante A
#
# Resuelva los ejercicios **1 y 2 de forma consecutiva**. Al terminar ambos, guarde el notebook en GitHub antes de entregar el control a su compañero o compañera.

# %% [markdown]
# ## Ejercicio 1 — NumPy: análisis básico de temperaturas
#
# Se registraron las siguientes temperaturas máximas, en grados Celsius, durante siete días:
#
# `[27, 29, 31, 28, 30, 32, 29]`
#
# Utilizando **NumPy**:
#
# 1. Cree un arreglo con las temperaturas.
# 2. Calcule la temperatura promedio.
# 3. Determine la temperatura máxima y mínima.
# 4. Muestre únicamente las temperaturas superiores al promedio.
#
# El resultado debe mostrar claramente cada cálculo.

# %%
# Ejercicio 1 - Escriba su solución aquí
temperaturas = np.array([27, 29, 31, 28, 30, 32, 29])

temperaturas = np.array([27, 29, 31, 28, 30, 32, 29])

promedio = np.mean(temperaturas)
maxima = np.max(temperaturas)
minima = np.min(temperaturas)

superiores = temperaturas[temperaturas > promedio]

print("Temperaturas superiores al promedio:", superiores)
# Out:
# Temperaturas superiores al promedio: [31 30 32]

# %% [markdown]
# ## Ejercicio 2 — Pandas: ventas de una cafetería
#
# Utilice los siguientes datos para crear un `DataFrame`:
#
# | Producto | Categoría | Precio | Unidades |
# |---|---|---:|---:|
# | Café | Bebida | 1800 | 12 |
# | Té | Bebida | 1500 | 8 |
# | Sándwich | Comida | 3200 | 6 |
# | Galleta | Comida | 1200 | 15 |
# | Jugo | Bebida | 2000 | 9 |
#
# Realice lo siguiente con **Pandas**:
#
# 1. Cree el `DataFrame`.
# 2. Agregue una columna llamada `Venta_Total`, calculada como `Precio * Unidades`.
# 3. Muestre únicamente los productos con una venta total superior a ₡15 000.
# 4. Calcule la venta total de todos los productos.

# %%
# Ejercicio 2 - Escriba su solución aquí

datos = {
    "Producto": ["Café", "Té", "Sándwich", "Galleta", "Jugo"],
    "Categoría": ["Bebida", "Bebida", "Comida", "Comida", "Bebida"],
    "Precio": [1800, 1500, 3200, 1200, 2000],
    "Unidades": [12, 8, 6, 15, 9]
}

df = pd.DataFrame(datos)

df["Venta_Total"] = df["Precio"] * df["Unidades"]

ventas_15 = df[df["Venta_Total"] > 15000]
print("Productos con venta total superior a ₡15 000:")
print(ventas_15)

venta_total_general = df["Venta_Total"].sum()
# Out:
# Productos con venta total superior a ₡15 000:
#    Producto Categoría  Precio  Unidades  Venta_Total
# 0      Café    Bebida    1800        12        21600
# 2  Sándwich    Comida    3200         6        19200
# 3   Galleta    Comida    1200        15        18000
# 4      Jugo    Bebida    2000         9        18000

# %% [markdown]
# ## Punto de control 1 — Guardar en GitHub
#
# **Estudiante A:** antes de continuar, guarde el notebook actualizado en GitHub.
#
# Commit sugerido:
#
# `Ejercicios 1 y 2 completados - Nombre Estudiante A`
#
# Una vez guardado, **Estudiante B debe abrir nuevamente el notebook desde GitHub** para asegurarse de trabajar sobre la última versión.

# %% [markdown]
# # Bloque 2 — Estudiante B
#
# Resuelva los ejercicios **3 y 4 de forma consecutiva** mientras comparte pantalla por Zoom. Al finalizar ambos ejercicios, guarde la versión final en GitHub.

# %% [markdown]
# ## Ejercicio 3 — NumPy: tiempos de ejecución
#
# Los siguientes valores representan el tiempo, en segundos, requerido por un programa para completar diez ejecuciones:
#
# `[2.4, 2.7, 2.5, 3.1, 2.9, 2.6, 3.0, 2.8, 2.5, 2.7]`
#
# Utilizando **NumPy**:
#
# 1. Cree un arreglo con los tiempos.
# 2. Calcule el promedio de ejecución.
# 3. Calcule la desviación estándar.
# 4. Cuente cuántas ejecuciones tardaron menos de 2.8 segundos.
# 5. Cree un nuevo arreglo con los tiempos redondeados a un decimal.

# %%
tiempos = np.array([2.4, 2.7, 2.5, 3.1, 2.9, 2.6, 3.0, 2.8, 2.5, 2.7])

# Calcular el promedio
promedio = np.mean(tiempos)

#Calcular la desviación estándar
desviacion = np.std(tiempos)

#Contar cuántas ejecuciones tardaron menos de 2.8 segundos
cantidad = np.sum(tiempos < 2.8)

#Crear un nuevo arreglo redondeado a un decimal
tiempos_redondeados = np.round(tiempos, 1)

print("Tiempos:", tiempos)
print("Promedio:", promedio)
print("Desviación estándar:", desviacion)
print("Ejecuciones menores a 2.8 segundos:", cantidad)
print("Tiempos redondeados:", tiempos_redondeados)
# Out:
# Tiempos: [2.4 2.7 2.5 3.1 2.9 2.6 3.  2.8 2.5 2.7]
# Promedio: 2.7199999999999998
# Desviación estándar: 0.2181742422927143
# Ejecuciones menores a 2.8 segundos: 6
# Tiempos redondeados: [2.4 2.7 2.5 3.1 2.9 2.6 3.  2.8 2.5 2.7]

# %% [markdown]
# ## Ejercicio 4 — Pandas: resultados de estudiantes
#
# Utilice los siguientes datos:
#
# | Estudiante | Quiz | Laboratorio |
# |---|---:|---:|
# | Ana | 85 | 90 |
# | Carlos | 70 | 78 |
# | Sofía | 95 | 92 |
# | Diego | 60 | 75 |
# | Valeria | 88 | 84 |
#
# Realice lo siguiente con **Pandas**:
#
# 1. Cree un `DataFrame` con los datos.
# 2. Agregue una columna `Promedio` calculada a partir de `Quiz` y `Laboratorio`.
# 3. Muestre únicamente los estudiantes con promedio mayor o igual a 80.
# 4. Ordene el `DataFrame` de mayor a menor según el promedio.
# 5. Muestre el nombre del estudiante con el promedio más alto.

# %%
#Crear el DataFrame
datos = {
    "Estudiante": ["Ana", "Carlos", "Sofía", "Diego", "Valeria"],
    "Quiz": [85, 70, 95, 60, 88],
    "Laboratorio": [90, 78, 92, 75, 84]
}

df = pd.DataFrame(datos)

#Agregar la columna Promedio
df["Promedio"] = (df["Quiz"] + df["Laboratorio"]) / 2

print("DataFrame completo:")
print(df)

#Mostrar estudiantes con promedio mayor o igual a 80
aprobados = df[df["Promedio"] >= 80]

print("\nEstudiantes con promedio >= 80:")
print(aprobados)

#Ordenar de mayor a menor según el promedio
df_ordenado = df.sort_values("Promedio", ascending=False)

print("\nDataFrame ordenado:")
print(df_ordenado)

#Mostrar el nombre del estudiante con el promedio más alto
estudiante_mayor = df.loc[df["Promedio"].idxmax(), "Estudiante"]

print("\nEstudiante con el promedio más alto:")
print(estudiante_mayor)
# Out:
# DataFrame completo:
#   Estudiante  Quiz  Laboratorio  Promedio
# 0        Ana    85           90      87.5
# 1     Carlos    70           78      74.0
# 2      Sofía    95           92      93.5
# 3      Diego    60           75      67.5
# 4    Valeria    88           84      86.0
#
# Estudiantes con promedio >= 80:
#   Estudiante  Quiz  Laboratorio  Promedio
# 0        Ana    85           90      87.5
# 2      Sofía    95           92      93.5
# 4    Valeria    88           84      86.0
#
# DataFrame ordenado:
#   Estudiante  Quiz  Laboratorio  Promedio
# 2      Sofía    95           92      93.5
# 0        Ana    85           90      87.5
# 4    Valeria    88           84      86.0
# 1     Carlos    70           78      74.0
# 3      Diego    60           75      67.5
#
# Estudiante con el promedio más alto:
# Sofía

# %% [markdown]
# ## Punto de control 2 — Guardar versión final en GitHub
#
# **Estudiante B:** guarde el notebook completo en GitHub.
#
# Commit sugerido:
#
# `Ejercicios 3 y 4 completados - Nombre Estudiante B`
#
# ### Verificación final
# - Los cuatro ejercicios deben estar resueltos.
# - Las celdas deben ejecutarse sin errores.
# - Deben existir al menos dos versiones/commits del trabajo realizado por la pareja.
# - Cada integrante debe poder explicar el código que desarrolló durante su turno.

# %% [markdown]
# ## Reflexión breve
#
# Respondan en conjunto, en un máximo de tres líneas:
#
# **¿Qué ventaja observaron al utilizar GitHub como repositorio para transferir el trabajo entre ambos integrantes y qué precaución deberían tener al trabajar sobre un mismo notebook?**

# %% [markdown]
# **Respuesta:**
#
# _Escriban aquí su respuesta._
